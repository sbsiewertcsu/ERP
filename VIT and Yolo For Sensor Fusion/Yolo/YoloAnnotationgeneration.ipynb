# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
from google.colab.patches import cv2_imshow
import random
import shutil
model_extra = YOLO('yolov8x.pt')

# %%
# Specify the source and destination directories
source_dir = '/content/drive/MyDrive/cleaned dataset/balanced dataset/testT/elephant'
destination_dir_images = '/content/drive/MyDrive/YoloCustonTraining/test/images'
destination_dir_labels_combine = '/content/drive/MyDrive/YoloCustonTraining/test/labels'
destination_dir_labels_imageOnly = '/content/drive/MyDrive/LabelsImageOnly/test'
destination_dir_labels_spectOnly = '/content/drive/MyDrive/LabelsSpectoOnly/test'

# Copy each item in the source directory to the destination directory
for item in os.listdir(source_dir):
    source_item_path = os.path.join(source_dir, item)
    destination_item_image = os.path.join(destination_dir_images, item)
    new_name = item[:-4] + '.txt'
    destination_item_label_combine = os.path.join(destination_dir_labels_combine, new_name)
    destination_item_label_imageOnly = os.path.join(destination_dir_labels_imageOnly, new_name)
    destination_item_label_spectOnly = os.path.join(destination_dir_labels_spectOnly, new_name)


    # Check if it's a file (not copying directories here)
    if os.path.isfile(source_item_path):
        shutil.copy(source_item_path, destination_item_image)
        img = cv2.imread(source_item_path)
        f = open(destination_item_label_combine, "x")
        g = open(destination_item_label_imageOnly, "x")
        h = open(destination_item_label_spectOnly, "x")
        try:
          results = model_extra.predict(img, classes = [20], device = 0, verbose = False)
          for result in results:
            boxes = result.boxes
        except Exception as e:
            print(f"An error occurred for result: {e}")
        try:
          for i in boxes:
            p1 = (int(i[0].xyxy[0][0]), int(i[0].xyxy[0][1]))
            p2 = (int(i[0].xyxy[0][2]), int(i[0].xyxy[0][3]))
            centre = ((p1[0]+p2[0])/2, (p1[1]+p2[1])/2)
            x = ((p1[0]+p2[0])/2)/img.shape[1]
            y = ((p1[1]+p2[1])/2)/img.shape[0]
            width = (p2[0]-p1[0])/img.shape[1]
            height = (p2[1]-p1[1])/img.shape[0]
            f.write(f"0 {x} {y} {width} {height}\n")
            g.write(f"0 {x} {y} {width} {height}\n")
        except Exception as e:
          print(f"An error occurred for box: {e}")

        f.write(f"0 0.5 0.75 1 0.5")
        h.write(f"0 0.5 0.75 1 0.5")
        f.close()
        g.close()
        h.close()

    else:
      pass

# %%
# Specify the source and destination directories
source_dir = '/content/drive/MyDrive/cleaned dataset/balanced dataset/trainT/elephant'
destination_dir_images = '/content/drive/MyDrive/YoloCustonTraining/train/images'
destination_dir_labels_combine = '/content/drive/MyDrive/YoloCustonTraining/train/labels'
destination_dir_labels_imageOnly = '/content/drive/MyDrive/LabelsImageOnly/train'
destination_dir_labels_spectOnly = '/content/drive/MyDrive/LabelsSpectoOnly/train'

# Copy each item in the source directory to the destination directory
for item in os.listdir(source_dir):
    source_item_path = os.path.join(source_dir, item)
    destination_item_image = os.path.join(destination_dir_images, item)
    new_name = item[:-4] + '.txt'
    destination_item_label_combine = os.path.join(destination_dir_labels_combine, new_name)
    destination_item_label_imageOnly = os.path.join(destination_dir_labels_imageOnly, new_name)
    destination_item_label_spectOnly = os.path.join(destination_dir_labels_spectOnly, new_name)


    # Check if it's a file (not copying directories here)
    if os.path.isfile(source_item_path):
        shutil.copy(source_item_path, destination_item_image)
        img = cv2.imread(source_item_path)
        f = open(destination_item_label_combine, "x")
        g = open(destination_item_label_imageOnly, "x")
        h = open(destination_item_label_spectOnly, "x")
        try:
          results = model_extra.predict(img, classes = [20], device = 0, verbose = False)
          for result in results:
            boxes = result.boxes
        except Exception as e:
            print(f"An error occurred for result: {e}")
        try:
          for i in boxes:
            p1 = (int(i[0].xyxy[0][0]), int(i[0].xyxy[0][1]))
            p2 = (int(i[0].xyxy[0][2]), int(i[0].xyxy[0][3]))
            centre = ((p1[0]+p2[0])/2, (p1[1]+p2[1])/2)
            x = ((p1[0]+p2[0])/2)/img.shape[1]
            y = ((p1[1]+p2[1])/2)/img.shape[0]
            width = (p2[0]-p1[0])/img.shape[1]
            height = (p2[1]-p1[1])/img.shape[0]
            f.write(f"0 {x} {y} {width} {height}\n")
            g.write(f"0 {x} {y} {width} {height}\n")
        except Exception as e:
          print(f"An error occurred for box: {e}")

        f.write(f"0 0.5 0.75 1 0.5")
        h.write(f"0 0.5 0.75 1 0.5")
        f.close()
        g.close()
        h.close()

    else:
      pass

# %%
# Specify the source and destination directories
source_dir = '/content/drive/MyDrive/cleaned dataset/balanced dataset/validationT/elephant'
destination_dir_images = '/content/drive/MyDrive/YoloCustonTraining/validate/images'
destination_dir_labels_combine = '/content/drive/MyDrive/YoloCustonTraining/validate/labels'
destination_dir_labels_imageOnly = '/content/drive/MyDrive/LabelsImageOnly/validate'
destination_dir_labels_spectOnly = '/content/drive/MyDrive/LabelsSpectoOnly/validate'

# Copy each item in the source directory to the destination directory
for item in os.listdir(source_dir):
    source_item_path = os.path.join(source_dir, item)
    destination_item_image = os.path.join(destination_dir_images, item)
    new_name = item[:-4] + '.txt'
    destination_item_label_combine = os.path.join(destination_dir_labels_combine, new_name)
    destination_item_label_imageOnly = os.path.join(destination_dir_labels_imageOnly, new_name)
    destination_item_label_spectOnly = os.path.join(destination_dir_labels_spectOnly, new_name)


    # Check if it's a file (not copying directories here)
    if os.path.isfile(source_item_path):
        shutil.copy(source_item_path, destination_item_image)
        img = cv2.imread(source_item_path)
        f = open(destination_item_label_combine, "x")
        g = open(destination_item_label_imageOnly, "x")
        h = open(destination_item_label_spectOnly, "x")
        try:
          results = model_extra.predict(img, classes = [20], device = 0, verbose = False)
          for result in results:
            boxes = result.boxes
        except Exception as e:
            print(f"An error occurred for result: {e}")
        try:
          for i in boxes:
            p1 = (int(i[0].xyxy[0][0]), int(i[0].xyxy[0][1]))
            p2 = (int(i[0].xyxy[0][2]), int(i[0].xyxy[0][3]))
            centre = ((p1[0]+p2[0])/2, (p1[1]+p2[1])/2)
            x = ((p1[0]+p2[0])/2)/img.shape[1]
            y = ((p1[1]+p2[1])/2)/img.shape[0]
            width = (p2[0]-p1[0])/img.shape[1]
            height = (p2[1]-p1[1])/img.shape[0]
            f.write(f"0 {x} {y} {width} {height}\n")
            g.write(f"0 {x} {y} {width} {height}\n")
        except Exception as e:
          print(f"An error occurred for box: {e}")

        f.write(f"0 0.5 0.75 1 0.5")
        h.write(f"0 0.5 0.75 1 0.5")
        f.close()
        g.close()
        h.close()

    else:
      pass

# %%
# Specify the source and destination directories
source_dir = '/content/drive/MyDrive/cleaned dataset/balanced dataset/validationT/nonelephant'
destination_dir_images = '/content/drive/MyDrive/YoloCustonTraining/validate/images'
destination_dir_labels_combine = '/content/drive/MyDrive/YoloCustonTraining/validate/labels'
destination_dir_labels_imageOnly = '/content/drive/MyDrive/LabelsImageOnly/validate'
destination_dir_labels_spectOnly = '/content/drive/MyDrive/LabelsSpectoOnly/validate'

# Copy each item in the source directory to the destination directory
for item in os.listdir(source_dir):
    source_item_path = os.path.join(source_dir, item)
    destination_item_image = os.path.join(destination_dir_images, item)
    new_name = item[:-4] + '.txt'
    destination_item_label_combine = os.path.join(destination_dir_labels_combine, new_name)
    destination_item_label_imageOnly = os.path.join(destination_dir_labels_imageOnly, new_name)
    destination_item_label_spectOnly = os.path.join(destination_dir_labels_spectOnly, new_name)


    # Check if it's a file (not copying directories here)
    if os.path.isfile(source_item_path):
        shutil.copy(source_item_path, destination_item_image)
        f = open(destination_item_label_combine, "x")
        g = open(destination_item_label_imageOnly, "x")
        h = open(destination_item_label_spectOnly, "x")
        f.close()
        g.close()
        h.close()

    else:
      pass

# %%
# Specify the source and destination directories
source_dir = '/content/drive/MyDrive/cleaned dataset/balanced dataset/trainT/nonelephant'
destination_dir_images = '/content/drive/MyDrive/YoloCustonTraining/train/images'
destination_dir_labels_combine = '/content/drive/MyDrive/YoloCustonTraining/train/labels'
destination_dir_labels_imageOnly = '/content/drive/MyDrive/LabelsImageOnly/train'
destination_dir_labels_spectOnly = '/content/drive/MyDrive/LabelsSpectoOnly/train'

# Copy each item in the source directory to the destination directory
for item in os.listdir(source_dir):
    source_item_path = os.path.join(source_dir, item)
    destination_item_image = os.path.join(destination_dir_images, item)
    new_name = item[:-4] + '.txt'
    destination_item_label_combine = os.path.join(destination_dir_labels_combine, new_name)
    destination_item_label_imageOnly = os.path.join(destination_dir_labels_imageOnly, new_name)
    destination_item_label_spectOnly = os.path.join(destination_dir_labels_spectOnly, new_name)


    # Check if it's a file (not copying directories here)
    if os.path.isfile(source_item_path):
        shutil.copy(source_item_path, destination_item_image)
        f = open(destination_item_label_combine, "x")
        g = open(destination_item_label_imageOnly, "x")
        h = open(destination_item_label_spectOnly, "x")
        f.close()
        g.close()
        h.close()

    else:
      pass

# %%
# Specify the source and destination directories
source_dir = '/content/drive/MyDrive/cleaned dataset/balanced dataset/testT/nonelephant'
destination_dir_images = '/content/drive/MyDrive/YoloCustonTraining/test/images'
destination_dir_labels_combine = '/content/drive/MyDrive/YoloCustonTraining/test/labels'
destination_dir_labels_imageOnly = '/content/drive/MyDrive/LabelsImageOnly/test'
destination_dir_labels_spectOnly = '/content/drive/MyDrive/LabelsSpectoOnly/test'

# Copy each item in the source directory to the destination directory
for item in os.listdir(source_dir):
    source_item_path = os.path.join(source_dir, item)
    destination_item_image = os.path.join(destination_dir_images, item)
    new_name = item[:-4] + '.txt'
    destination_item_label_combine = os.path.join(destination_dir_labels_combine, new_name)
    destination_item_label_imageOnly = os.path.join(destination_dir_labels_imageOnly, new_name)
    destination_item_label_spectOnly = os.path.join(destination_dir_labels_spectOnly, new_name)


    # Check if it's a file (not copying directories here)
    if os.path.isfile(source_item_path):
        shutil.copy(source_item_path, destination_item_image)
        f = open(destination_item_label_combine, "x")
        g = open(destination_item_label_imageOnly, "x")
        h = open(destination_item_label_spectOnly, "x")
        f.close()
        g.close()
        h.close()

    else:
      pass
